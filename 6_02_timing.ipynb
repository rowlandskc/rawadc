# %%
### import necessary packages ###
import matplotlib.pylab as plt  ##plotting 
from rawice import *            ##all modules from rawice.py
import warnings
import numpy as np
import os

warnings.filterwarnings('ignore')

# %%
## location of raw acq data
notebook_path = os.path.abspath("6_02_timing.ipyn")
folder_path = os.path.join(os.path.dirname(notebook_path), "gbo_rawadc/")
print(folder_path)
path = os.path.join(os.path.dirname(notebook_path), "gbo_rawadc/000000.h5")

#path = "/Users/rowlandskc/WVU/rawadc/000040.h5"
#folder_path = "/Users/rowlandskc/WVU/rawadc"

## File 000006 is bad for some reason

## load data from file to object 'acq'

acq = raw_acq(path)

#help(raw_acq)

acq.adc_input

#set the input 
tm4_input = [0,15,12]
#tm4_input2 = [0,15,0]
#tm5101_input = [0,0,3]
#print(np.sort(glob.glob("/Users/rowlandskc/WVU/rawadc_updated/000000.h5")))
#r=raw_acq(np.sort(glob.glob("/Users/rowlandskc/WVU/rawadc_updated/000000.h5")))
# Out:
# /Users/rowlandskc/WVU/gbo_rawadc/
# Loaded raw acq HDF5 file ...

# %%
acq.diagostics()
# Out:
# raw ACQ diagnostics ...
#
# file_name: /home/masuilab/data/raw_acq/20230602T172738Z_GBO_rawadc/000000.h5
# rawadc_version: 0.1
#
# ctime Timestamp of first raw_adc frame: 2023-06-02T13:27:38.527004
# ctime Timestamp of last raw_adc frame: 2023-06-02T18:16:20.911868
#
# Time between raw_adc captures is either [ 0.2  0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2.   2.2  2.4  2.6  2.8
#   3.   3.2  3.4  3.6  4.6  6.   7.2 10. ] seconds
# good_fpga len: 487
# len time_since_capture: 485
