# %%
### import necessary packages ###
#%matplotlib notebook
import matplotlib.pylab as plt  ##plotting 
from rawice import *            ##all modules from rawice.py
import warnings
import numpy as np
import os
from scipy.optimize import curve_fit

warnings.filterwarnings('ignore')

# %%
## location of raw acq data
notebook_path = os.path.abspath("6_26_23_full.ipyn")
folder_path = os.path.join(os.path.dirname(notebook_path), "6_26_small/")
print(folder_path)
path = os.path.join(os.path.dirname(notebook_path), "6_26_small/000018_maser.h5")

#path = "/Users/rowlandskc/WVU/rawadc/000040.h5"
#folder_path = "/Users/rowlandskc/WVU/rawadc"



## load data from file to object 'acq'
acq = raw_acq(path)
#help(raw_acq)
acq.adc_input

#set the input 
tm4_input = [0,15,12]
# Out:
# /Users/rowlandskc/WVU/6_26_small/
# Loaded raw acq HDF5 file ...

# %%
tm4 = acq.check_input(tm4_input)
tm4.inspect_maser()
# Out:
# Checking input [0, 15, 12] ...
# 2.034389024177444

# %%
#tm4.get_curve_fit()

# %% [markdown]
# should take around 35 minutes if the time to process it is the same as 487 length

# %%
#tm4.get_single_curve_fit(i=0)

# %%
tm4_clock = analyse_maser(folder_path, tm4_input)
# Out:
# /Users/rowlandskc/WVU/6_26_small/000018_maser.h5
# 1
# Loaded raw acq HDF5 file ... .....................................................................] 0/1
# Checking input [0, 15, 12] ...
# 2.034389024177444
# 1
# Done Computing Delay: ############################################################################] 1/1
#
# DONE reading files and getting delays

# %%
tm4_clock.plot_delays()
plt.savefig("6_26_23_maser_delays_fixed_000018.pdf", format="pdf")

# %%
xlist = [val for val in range(0+1, 65536)]#used to be 2049

xval = [(val*(1.25e-9)/60/60) for val in xlist]

fig, ax = plt.subplots(figsize=(20,10))      #HEY LOOK AT THIS!!!!
#[:512] before
plt.plot(tm4_clock.fpgatime[:65536]*2.56e-6/60/60, 10e8*((tm4_clock.taus[:65536])-tm4_clock.taus[0]), c = 'silver', ls="--")#, marker = ','
ax.errorbar(tm4_clock.fpgatime[:65536]*2.56e-6/60/60, (np.array(tm4.tau_shift[:65536])-tm4.tau_shift[0]), yerr=tm4.tau_err[:65536], fmt=',', ecolor='red')
ax.set_title('Tau shift')
plt.xlabel("Hours")
plt.ylabel(r" $\Delta(\tau)$ (ns)")
#plt.savefig("6_26_23_maser_tau_shift.pdf", format="pdf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 8
#       6 #[:512] before
#       7 plt.plot(tm4_clock.fpgatime[:65536]*2.56e-6/60/60, 10e8*((tm4_clock.taus[:65536])-tm4_clock.taus[0]), c = 'silver', ls="--")#, marker = ','
# ----> 8 ax.errorbar(tm4_clock.fpgatime[:65536]*2.56e-6/60/60, (np.array(tm4.tau_shift[:65536])-tm4.tau_shift[0]), yerr=tm4.tau_err[:65536], fmt=',', ecolor='red')
#       9 ax.set_title('Tau shift')
#      10 plt.xlabel("Hours")
#
# AttributeError: 'check_input' object has no attribute 'tau_shift'

# %%
#tm4_clock.taus
difference= (tm4_clock.fpgatime[:65536]*2.56e-6/60/60)-(10e8*((tm4_clock.taus[:65536])-tm4_clock.taus[0]))
print(difference)

# %%
#tm4.tau_shift
