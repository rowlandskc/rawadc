# %%
### import necessary packages ###
import matplotlib.pylab as plt  ##plotting 
from rawice import *            ##all modules from rawice.py
import warnings
import numpy as np
import os

warnings.filterwarnings('ignore')

# %%
## location of raw acq data
notebook_path = os.path.abspath("6_26_23_timing_test.ipyn")
folder_path = os.path.join(os.path.dirname(notebook_path), "6_26_23/")
print(folder_path)
path = os.path.join(os.path.dirname(notebook_path), "6_26_23/000020_maser.h5")

#path = "/Users/rowlandskc/WVU/rawadc/000040.h5"
#folder_path = "/Users/rowlandskc/WVU/rawadc"

## File 000006 is bad for some reason

## load data from file to object 'acq'
acq = raw_acq(path)
#help(raw_acq)
acq.adc_input

#set the input 
tm4_input = [0,15,12]
#tm4_input2 = [0,15,0]
#tm5101_input = [0,0,3]
# Out:
# /Users/rowlandskc/WVU/6_26_23/
# Loaded raw acq HDF5 file ...

# %%
#tm4 = acq.check_input(tm4_input)
#tm4.inspect_maser()

#tm4.plot_single_input_diagnostics()

#use
#fig, ax = plt.subplots(figsize=(20, 10))
#plt.plot(tm4.time_streams[0])

#tm4b = acq.check_input(tm4_input2)
#tm4b.inspect_maser()
#fig, ax =plt.subplots(figsize=(20,10))
#plt.plot(tm4b.time_streams[0])

# %%
#useful
#tm4.get_timestream_for_input()

# %%
#tm4.time_stamps

# %%
#useful just speeding stuff up
#tm4_clock = analyse_maser(folder_path, tm4_input)

# %%
#files = glob.glob(folder_path + "*[!.lock]")

# %%
#files

# %%
#folder_path

# %%
#useful, just speeding stuff up
#tm4_delays = tm4_clock.plot_delays()
#plt.savefig("maser_all_delays.pdf", format="pdf")

# %%
#allanplot = tm4_clock.get_allan_deviation()
#plt.savefig("maser_Allan_deviation.pdf", format="pdf")

# %% [markdown]
# Recreate automation test

# %%
acq.diagostics()
# Out:
# raw ACQ diagnostics ...
#
# archive_version: 2.4.0
# collection_server: hostname
# git_version_tag: 0.1
# file_name: /home/masuilab/data/raw_acq/20230612T184915Z_GBOmaser_rawadc/000020_maser.h5
# data_type: ADC snapshot data
# system_user: root
# rawadc_version: 0.1
# Timestamping_warning: Done on file write, may be significantly different from snapshot acquistion time
#
# ctime Timestamp of first raw_adc frame: 2023-06-24T19:55:49.870760
# ctime Timestamp of last raw_adc frame: 2023-06-25T10:21:18.415989
#
# Time between raw_adc captures is either [ 0.2  0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2.   2.2  2.4  2.6  2.8
#   3.   3.2  3.4  3.6  3.8  4.   4.2  4.4  4.6  4.8  5.   5.2  5.6  5.8
#   6.   6.2  6.4  6.6  6.8  7.   7.2  7.4  7.6  7.8  8.   8.2  8.4  8.6
#   8.8  9.   9.2  9.4  9.6  9.8 10.  10.2 10.4 10.6 10.8 11.  11.2 11.4
#  11.6 11.8 12.  12.2 12.4 12.6 12.8 13.  13.2 13.4 13.6 13.8 14.  14.2
#  14.4 14.6 14.8 15.  15.2 15.4 15.6 15.8 16.  16.2 16.4 16.8 17.  17.2
#  17.4 17.8 18.2 18.4 18.6 19.2 20.  20.4 21.2 21.8 22.  22.2 22.4 22.6
#  22.8 23.  23.2 23.4 23.6 23.8 24.  24.2 24.4 24.6 24.8 25.  25.2 25.4
#  25.6 25.8 26.2 26.4 26.6 27.  27.4 29.4 30.2 36.6 37.  37.8] seconds
# fpga_counts len: 65536
# [412186406250 412186484375 412186562500 ... 432470859375 432470937500
#  432471015625]
# len: 65535
# fpga_counts len: 65536
# [412186406250 412186484375 412186562500 ... 432470859375 432470937500
#  432471015625]
# len: 65535
