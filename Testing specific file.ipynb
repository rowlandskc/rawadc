# %%
# %matplotlib inline

# %%
from rawice import *
import matplotlib.pyplot as plt

# %%
file_name = "/Users/rowlandskc/WVU/complete_maser_run_6_22_23/000000_maser.h5"
input_to_check = [0, 15, 12]
raw_acq(file_name)
maser = raw_acq.check_input(input_to_check)
maser.inspect_maser()
timestm = maser.time_fpga_count
tsmt = (timestm - timestm[0])*2.56e-6/3600
plt.figure()
plt.scatter(tsmt, maser.tau/1e-9, s= 0.5, c = 'k', marker = '.')
plt.xlabel("Hours")
plt.ylabel(r" $\Delta(\tau)$ (ns)")
(taus, adevs, errors, ns) = allan.oadev(maser.tau, taus = (timestm - timestm[0])*2.56e-6)
plt.figure()
plt.loglog(taus,adevs, c = 'k', lw = 1)

plt.ylabel("Allan Deviation")
plt.xlabel("Time (s)")
plt.grid()
# Out:
# Loaded raw acq HDF5 file ...
# Checking input [0, 15, 12] ...
# -1.1055118485357438

# %%
file_name = "/Users/rowlandskc/WVU/rawadc/000040.h5"
input_to_check = [0, 15, 0]
raw_acq(file_name)
maser = raw_acq.check_input(input_to_check)
maser.inspect_maser()
timestm = maser.time_fpga_count
tsmt = (timestm - timestm[0])*2.56e-6/3600
plt.figure()
plt.scatter(tsmt, maser.tau/1e-9, s= 0.5, c = 'k', marker = '.')
plt.xlabel("Hours")
plt.ylabel(r" $\Delta(\tau)$ (ns)")
(taus, adevs, errors, ns) = allan.oadev(maser.tau, taus = (timestm - timestm[0])*2.56e-6)
plt.figure()
plt.loglog(taus,adevs, c = 'k', lw = 1)

plt.ylabel("Allan Deviation")
plt.xlabel("Time (s)")
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 file_name = "/Users/rowlandskc/WVU/rawadc/000040.h5"
#       2 input_to_check = [0, 15, 0]
# ----> 3 raw_acq(file_name)
#       4 maser = raw_acq.check_input(input_to_check)
#       5 maser.inspect_maser()
#
# File ~/WVU/rawice.py:103, in raw_acq.__init__(self, raw_acq_file, diagnostics)
#      92 '''
#      93
#      94 Inputs: a string (path to a single acq file), boolean initialized to false
#    (...)
#     100
#     101 '''
#     102 self.file = raw_acq_file
# --> 103 self.read()
#     104 if diagnostics:
#     105     self.diagostics()
#
# File ~/WVU/rawice.py:117, in raw_acq.read(self)
#     107 def read(self):
#     108     '''
#     109
#     110     Inputs: n/a
#    (...)
#     115
#     116     '''
# --> 117     self.hdf5 = h5py.File(self.file,"r")
# ...
